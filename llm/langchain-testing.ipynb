# %%
from langchain.agents import create_agent
# Out:
# c:\Users\jayes\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\utils\pydantic.py:41: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1

# %%
agent=create_agent(model="google_genai:gemini-2.5-flash-lite",system_prompt="You are a comedian")

# %%
result=agent.invoke({"messages":[{"role":"user","content":"Tell me a joke"}]})
print(result["messages"][-1].content)
# Out:
# Why don't scientists trust atoms?
#
# Because they make up everything!
