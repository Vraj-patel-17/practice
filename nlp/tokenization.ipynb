# %%
from nltk.tokenize import sent_tokenize

# %%
corpus="""Hello World! This is a paragraph . This file is for practice only"""

# %%
##tokenization
#para to sentence
sent_tokenize(corpus)
# Out:
# ['Hello World!', 'This is a paragraph .', 'This file is for practice only']

# %%
#sentence,para to words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'World',
#  '!',
#  'This',
#  'is',
#  'a',
#  'paragraph',
#  '.',
#  'This',
#  'file',
#  'is',
#  'for',
#  'practice',
#  'only']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'World',
#  '!',
#  'This',
#  'is',
#  'a',
#  'paragraph',
#  '.',
#  'This',
#  'file',
#  'is',
#  'for',
#  'practice',
#  'only']
